# %% [markdown]
# <a href="https://colab.research.google.com/github/guydavid105/gd496_ads_2024/blob/main/ads_course_assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assessment for Advanced Data Science
# # *Data Pipelines*

# %% [markdown]
# ## Radzim Sendyka, Christian Cabrera, Carl Henrik Ek and Neil D. Lawrence
#
# ### 19 November 2024

# %% [markdown]
# Welcome to the course assessment for the Advanced Data Science unit. In this assessment, you will build two data pipelines and prediction systems.
#
# The maximum total mark for this assessment is 20. That mark is split into two miniprojects below.
# - The first miniproject is worth 7 marks.
# - The second miniproject is worth 13 marks.
#
# *The check Session for this Assessment is 03 December 2024.*

# %% [markdown]
# # Task 1 (7 marks)

# %% [markdown]
# This example project builds on your experience from the practicals, using Open Street Maps, and connecting them to real-world datasets.
#
# Your prediction system will be based on data from the 2021 UK Census, and Open Street Maps.

# %% [markdown]
# ### Build a data pipeline and prediction system.
#
# Structure your system around the [Access-Assess-Address](https://inverseprobability.com/talks/notes/access-assess-address-a-pipeline-for-automated-data-science.html) framework for automated data science.
# Use the framework of [Data Readiness Levels](https://inverseprobability.com/publications/data-readiness-levels.html) to track the state of your datasets throughout the process.
# Visualise your data and predictions using appropriate charts and graphics.
# Remember, your notebook should tell a story.
#
# 1.1. Download the data from online sources. In this task you will need:
#   - UK Census Data
#     - The UK Census data file for and Socio-economic Classification (NS SEC) [here](https://www.ons.gov.uk/datasets/TS062/editions/2021/versions/5) or [here](https://www.nomisweb.co.uk/sources/census_2021_bulk). Use the most detailed area type (Output Areas).
#     - One other UK Census data file of your choosing [here](https://www.ons.gov.uk/search?topics=9731,6646,3845,9497,4262,4128,7755,4994,6885,9724,7367&filter=datasets) or [here](https://www.nomisweb.co.uk/sources/census_2021_bulk). Use the most detailed area type available.
#     - Geographic coordinates of Census Output Areas [here](https://www.data.gov.uk/dataset/4d4e021d-fe98-4a0e-88e2-3ead84538537/output-areas-december-2021-boundaries-ew-bgc-v2).
#   - Spatial data
#     - Set up an API connection to Open Street Maps [here](https://osmnx.readthedocs.io/en/stable/). Optionally, to be able to use more data in training, you might want to also download the entire map for England (or more) [here](https://download.openstreetmap.fr/extracts/) or [here](https://wiki.openstreetmap.org/wiki/Planet.osm).
#
# 1.2. Structure the data, and upload it to your AWS database.
#
# - Census datasets can be huge and unwieldy to manipulate directly in python frameworks such as pandas. As a result we will host the data in a relational database.
#
# - Using a cloud hosted database (such as MariaDB hosted on the AWS RDS service),  you will construct a database containing tables that contain per-output-area data, latitudes and longitudes of the output areas, and potentially, extracted selected open street maps features from the country-wide data file.
#
# - Make sure you set the correct indices on your data, which will allow your code to run much faster. Hint: create an index on any columns you will be looking up, and joint indices if your lookup involves multiple columns (like coordinates).
#
# You will likely find the following resources helpful.
#
# - Lecture 1, 2 and 3.
# - Lab class 1 and 2.
#
#
# - *Note, this particular dataset could probably be handled directly in pandas, but you are explicitly tasked with using a database. This is a compromise from previous iterations of this course, where students spent quite a lot of time struggling from the size of the data. This is an opportunity for you to demonstrate your skills, as well as prepare for the second part of the assessment where databases might be necessary. Approach that do not use databases where needed will be penalised during marking.*
#
#
# 2.0. Explore the data.
#
#   - To make predictions you will augment your data with information obtained from Open Street Map: an open license source of mapping information. You will need to use the techniques you have learnt in the course to indentify and incorporate useful features for your prediction tasks.
#   - Look at the percentage of students (NS SEC code L15) in the individual output areas, and explore how it's related to various types of open street map features in those locations. Use the relationships you found to suggest the features to be used in a system that predicts percentage of students in a given area.
#   - Do the same for an additional census variable (e.g., the average age in a given area).
#
# 3.0. Make a prediction system.
# - Use Open Street Maps to predict Socio-Economic Status - in particular, the percent of full time students, from OSM features. Your function should take as input a coordinate pair (you can assume it will be in England), and return an estimate for the share of students in that area.
#
# - Do the same for the additional census variable you selected in the previous step.
#
# Hints:
#
#   - *Some of the census data sheets are very detailed. You might want to try "boiling them down" to some aggregate value or selecting just the most important columns.*
#
#   - *This assignment is focused on data pipelines, rather than machine learning, so we do not expect any advanced architectures here - a linear model or similar is perfectly fine.*
#
#   - *For data exploration, or picking your second dataset, you may find useful the [interactive map](https://www.ons.gov.uk/census/maps/) of the census data.*

# %% [markdown]
# ### Story.
#
# - Remember the notebook you create should tell a story, any code that is not critical to that story can safely be placed into the associated analysis library and imported for use (structured as given in the Fynesse template). Make sure your decisions are well substanciated and flow nicely throughout the notebook, with clear explanations.
#
# - Explain everything you do. Why is your question important, why you selected the datasets you did, why did you join them how you did, why did you look at the things you looked at.
#
# Make sure in your notebook you discuss the design decisions you made in your pipeline and prediction system. How did you structure your notebook? How did you track data readiness? Which aspects of your system could be improved further?
#
# Make sure you compare how you predict student population and your second chosen property. What differences are there, in the underlying data, process, and results?
#
# Make sure you discuss the reusability of your data pipeline and prediction system. What changes to the underlying data/system is it resilient to, and what isn't it? What work would need to be done to adjust it to answer questions about other statistics, or a different country, instead?

# %% [markdown]
# ### Fynesse library.
#
# - Alongside your implementation you will provide a short repository overview describing how you have implemented the different parts of the project and where you have placed those parts in your code repository. You will submit your code alongside a version of this notebook that will allow your examiner to understand and reconstruct the thinking behind your analysis. This notebook is structured to help you in creating that description and allow you to understand how we will allocate the marks. You should make use of the Fynesse framework (https://github.com/lawrennd/fynesse_template) for structuring your code.
#
# - One artefact to be included in your submission is a python library structured according to the "Access, Assess, Address" standard for data science solutions. You will submit this library alongside your code. Use the cell below to perform the necessary installation instructions for your library.
# You should base your module on the template repository given by the Fynesse template repository. That should make it pip-installable as below.
# `%pip install git+https://github.com/lawrennd/fynesse_template.git`. You can either replace fynesse with the name you've given your analysis module or you can leave the name as fynesse if you prefer.
#
# - Remember the notebook you create should tell a story, any code that is not critical to that story can safely be placed into the associated analysis library and imported for use (structured as given in the Fynesse template). Remember to include you fynesse library in your submission.

# %% [markdown]
# ## Access

# %%
# install your library here
# %pip install git+https://github.com/lawrennd/fynesse_template.git # TODO: change to your library
# %pip install osmnx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 1.9 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import osmnx as ox
# TODO: more imports here
# import fynesse

# %%
output_areas = pd.read_csv("Output_Areas.csv")
output_areas = output_areas.rename(columns={"LONG": "LON"})
output_areas
# Out:
#            FID     OA21CD   LSOA21CD              LSOA21NM  \
# 0            1  E00000001  E01000001   City of London 001A
# 1            2  E00000003  E01000001   City of London 001A
# 2            3  E00000005  E01000001   City of London 001A
# 3            4  E00000007  E01000001   City of London 001A
# 4            5  E00000010  E01000003   City of London 001C
# ...        ...        ...        ...                   ...
# 188875  188876  W00010693  W01000062          Gwynedd 001A
# 188876  188877  W00010694  W01000645  Carmarthenshire 006C
# 188877  188878  W00010695  W01000664  Carmarthenshire 016C
# 188878  188879  W00010696  W01001923  Carmarthenshire 026G
# 188879  188880  W00010697  W01000667  Carmarthenshire 023C
#
#                    LSOA21NMW   BNG_E   BNG_N       LAT      LON  \
# 0                             532250  181864  51.52022 -0.09523
# 1                             532171  181819  51.51983 -0.09638
# ...

# %%
min_lat = min(output_areas['LAT'])
max_lat = max(output_areas['LAT'])
min_lon = min(output_areas['LON'])
max_lon = max(output_areas['LON'])

print(str(min_lat) + " " + str(max_lat))
print(str(min_lon) + " " + str(max_lon))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0ddde562d13f> in <cell line: 1>()
# ----> 1 min_lat = min(output_areas['LAT'])
#       2 max_lat = max(output_areas['LAT'])
#       3 min_lon = min(output_areas['LON'])
#       4 max_lon = max(output_areas['LON'])
#       5
#
# NameError: name 'output_areas' is not defined

# %%
# Your code here
import requests
import zipfile
import io
import os
import pandas as pd


def download_census_data(year, code, base_dir=''):
  year = str(year)
  url = f'https://www.nomisweb.co.uk/output/census/{year}/census{year}-{code.lower()}.zip'
  extract_dir = os.path.join(base_dir, os.path.splitext(os.path.basename(url))[0])

  if os.path.exists(extract_dir) and os.listdir(extract_dir):
    print(f"Files already exist at: {extract_dir}.")
    return

  os.makedirs(extract_dir, exist_ok=True)
  response = requests.get(url)
  response.raise_for_status()

  with zipfile.ZipFile(io.BytesIO(response.content)) as zip_ref:
    zip_ref.extractall(extract_dir)

  print(f"Files extracted to: {extract_dir}")

def load_census_data(year, code, level='msoa'):
  return pd.read_csv(f'census{year}-{code.lower()}/census{year}-{code.lower()}-{level}.csv')

# %%
download_census_data(2021, 'TS062')
statistics_df = load_census_data(2021, 'TS062', level='oa')
statistics_df.columns = ['year', 'geography', 'OA21CD', 'total', 'L1L3', 'L4L6', 'L7', 'L8L9', 'L10L11', 'L12', 'L13', 'L14', 'L15']
statistics_df = pd.merge(statistics_df, output_areas, on="OA21CD")
statistics_df = statistics_df.drop(columns=["FID", "LSOA21CD", "LSOA21NM", "LSOA21NMW", "BNG_E", "BNG_N", "GlobalID"])
statistics_df
# Out:
# Files extracted to: census2021-ts062
#         year  geography     OA21CD  total  L1L3  L4L6  L7  L8L9  L10L11  L12  \
# 0       2021  E00000001  E00000001    159    80    38  13     9       3    5
# 1       2021  E00000003  E00000003    222    96    58   8    26       2    5
# 2       2021  E00000005  E00000005    103    37    28   8    21       0    3
# 3       2021  E00000007  E00000007    140    62    39   5    11       3    3
# 4       2021  E00000010  E00000010    170    34    45  17    27       7   10
# ...      ...        ...        ...    ...   ...   ...  ..   ...     ...  ...
# 188875  2021  W00010693  W00010693    737     2     8   5     8       7    9
# 188876  2021  W00010694  W00010694    304    35    87  40    31      23   26
# 188877  2021  W00010695  W00010695    154    12    44  22    15      12   15
# 188878  2021  W00010696  W00010696    176    32    55  26    14       9   13
# 188879  2021  W00010697  W00010697    215    16    59  40    21      10   30
#
# ...

# %%
download_census_data(2021, 'TS067')
qualification_df = load_census_data(2021, 'TS067', level='oa')
qualification_df.columns = ['year', 'geography', 'OA21CD', 'total', 'None', 'L1', 'L2', 'Apprenticeship', 'L3', 'L4', 'Other']
qualification_df = pd.merge(qualification_df, output_areas, on="OA21CD")
qualification_df = qualification_df.drop(columns=["FID", "LSOA21CD", "LSOA21NM", "LSOA21NMW", "BNG_E", "BNG_N", "GlobalID"])
qualification_df
# Out:
# Files extracted to: census2021-ts067
#         year  geography     OA21CD  total  None  L1  L2  Apprenticeship   L3  \
# 0       2021  E00000001  E00000001    160     4   7  10               1   11
# 1       2021  E00000003  E00000003    221     5   3   8               1   20
# 2       2021  E00000005  E00000005    106     3   2   3               3    7
# 3       2021  E00000007  E00000007    139     5   2   5               1    7
# 4       2021  E00000010  E00000010    172    15  15  18               0   23
# ...      ...        ...        ...    ...   ...  ..  ..             ...  ...
# 188875  2021  W00010693  W00010693    737    32  12  52              11  468
# 188876  2021  W00010694  W00010694    302    30  21  45              10   50
# 188877  2021  W00010695  W00010695    154    20   7  26               9   37
# 188878  2021  W00010696  W00010696    177    19  15  20               5   32
# 188879  2021  W00010697  W00010697    213    23   8  35              11   48
#
# ...

# %%
# %pip install pymysql
# %pip install sqlalchemy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 1.8 MB/s eta 0:00:00
# ...

# %%
# %load_ext sql
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
import yaml
from ipywidgets import interact_manual, Text, Password

# %%
@interact_manual(username=Text(description="Username:"),
                password=Password(description="Password:"),
                url=Text(description="URL:"),
                port=Text(description="Port:"))
def write_credentials(username, password, url, port):
    with open("credentials.yaml", "w") as file:
        credentials_dict = {'username': username,
                           'password': password,
                           'url': url,
                           'port': port}
        yaml.dump(credentials_dict, file)
# Out:
# interactive(children=(Text(value='', description='Username:'), Password(description='Password:'), Text(value='…

# %%
with open("credentials.yaml") as file:
  credentials = yaml.safe_load(file)
username = credentials["username"]
password = credentials["password"]
url = credentials["url"]
port = credentials["port"]

# %%
# %sql mariadb+pymysql://$username:$password@$url?local_infile=1
# %sql SHOW databases
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 7 rows affected.
# [('ads_2024',),
#  ('information_schema',),
#  ('innodb',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('tmp',)]

# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine(f'mysql+pymysql://{username}:{password}@{url}/{"ads_2024"}')

# %%
# %sql USE `ads_2024`;
# %sql SHOW TABLES;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 7 rows affected.
# [('oa_data',),
#  ('osm_nodes',),
#  ('postcode_data',),
#  ('pp_data',),
#  ('prices_coordinates_data',),
#  ('qualification_data',),
#  ('statistics_data',)]

# %%
output_areas.to_sql('oa_data', con=engine, if_exists='replace', index=True)
# Out:
# 188880

# %%
statistics_df.to_sql('statistics_data', con=engine, if_exists='replace', index=True)
qualification_df.to_sql('qualification_data', con=engine, if_exists='replace', index=True)
# Out:
# 188880

# %%
# %sql USE `ads_2024`;
# %sql SELECT * FROM statistics_data LIMIT 2;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 2 rows affected.
# [(0, 2021, 'E00000001', 'E00000001', 159, 80, 38, 13, 9, 3, 5, 5, 4, 2, 51.52022, -0.09523, 6949.15148162842, 421.166161134957),
#  (1, 2021, 'E00000003', 'E00000003', 222, 96, 58, 8, 26, 2, 5, 2, 5, 20, 51.51983, -0.09638, 4492.41107177734, 307.714652773369)]

# %%
# %sql USE `ads_2024`;
# %sql CREATE INDEX idx_oa_lat_lon on oa_data(LAT, LON);
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# []

# %%
# %sql USE `ads_2024`;
# %sql CREATE INDEX idx_statistics_lat_lon on statistics_data(LAT, LON);
# %sql CREATE INDEX idx_statistics_code on statistics_data(OA21CD);
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# []

# %%
# %sql USE `ads_2024`;
# %sql CREATE INDEX idx_qualification_lat_lon on qualification_data(LAT, LON);
# %sql CREATE INDEX idx_qualification_code on qualification_data(OA21CD);
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# []

# %%
# %sql USE `ads_2024`;
# %sql SELECT * FROM qualification_data LIMIT 2;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 2 rows affected.
# [(0, 2021, 'E00000001', 'E00000001', 160, 4, 7, 10, 1, 11, 122, 5, 51.52022, -0.09523, 6949.15148162842, 421.166161134957),
#  (1, 2021, 'E00000003', 'E00000003', 221, 5, 3, 8, 1, 20, 184, 0, 51.51983, -0.09638, 4492.41107177734, 307.714652773369)]

# %%
# %pip install osmium
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 14.9 MB/s eta 0:00:00
# ...

# %%
uk_min_lon, uk_max_lon = -10.0, 2.0
uk_min_lat, uk_max_lat = 49.0, 61.0
tile_bounding_boxes = {}
tile_counter = 0

for lon in range(int(uk_min_lon), int(uk_max_lon)):
    for lat in range(int(uk_min_lat), int(uk_max_lat)):
        tile_bounding_boxes[tile_counter] = (lon, lon + 1, lat, lat + 1)
        tile_counter += 1

# %%
final_tiles = []
for k, (w, e, s, n) in tile_bounding_boxes.items():
  if w > max_lon or e < min_lon or s > max_lat or n < min_lat:
    continue
  final_tiles.append(k)

# %%
import osmium

class OSMHandler(osmium.SimpleHandler):
    def __init__(self):
        super().__init__()
        self.nodes = []
        self.ways = []
        self.relations = []

    def node(self, n):
        if n.tags:
          self.nodes.append({
              'id': n.id,
              'lat': n.location.lat,
              'lon': n.location.lon,
              'tags': dict(n.tags)
          })

    def way(self, w):
        if w.tags:
          self.ways.append({
              'id': w.id,
              'nodes': [n.ref for n in w.nodes],
              'tags': dict(w.tags)
          })

    def relation(self, r):
        if r.tags:
          self.relations.append({
              'id': r.id,
              'members': [(m.ref, m.role) for m in r.members],
              'tags': dict(r.tags)
          })

handler = OSMHandler()

# %%
import json

for i in final_tiles:
    handler.apply_file(f"tile_{i}.osm.pbf")
    nodes_df = pd.DataFrame(handler.nodes)
    nodes_df['tags'] = nodes_df['tags'].apply(json.dumps)
    nodes_df = nodes_df.drop_duplicates()
    nodes_df.to_sql('osm_nodes', con=engine, if_exists='append', index=False)
    print("Added osm tile " + str(i) + " to the database")
# Out:
# Added osm tile 36 to the database
#            id                                            members  \
# 0       58447  [(660867243, label), (107775, admin_centre), (...
# 1       62149  [(838090640, label), (107775, admin_centre), (...
# 2      151339  [(386844697, outer), (778014838, outer), (1882...
# 3      158039  [(239166714, outer), (239119715, outer), (2390...
# 4     1987628  [(386844697, outer), (778014838, outer), (1882...
# ..        ...                                                ...
# 440  18109678  [(238155321, outer), (238155316, outer), (2381...
# 441  18109679  [(1319818963, outer), (1319818960, outer), (13...
# 442  18109680         [(1144328757, outer), (1319818973, inner)]
# 443  18109681  [(1319819026, outer), (834580711, inner), (131...
# 444  18109682  [(311820363, outer), (1319819057, inner), (131...
#
#                                                   tags
# 0    {"ISO3166-2": "GB-ENG", "admin_level": "4", "a...
# ...

# %%
# %sql USE `ads_2024`;
# %sql CREATE INDEX idx_nodes_lat_long ON osm_nodes(lat, lon);
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# []

# %%
# %sql USE `ads_2024`;
# %sql SELECT DISTINCT * FROM osm_nodes WHERE lat BETWEEN 49.0 AND 50.0 AND lon BETWEEN -7.0 AND -6.0 LIMIT 5;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 5 rows affected.
# [(380749185, 49.8717355, -6.3910897, '{"name": "Western Rocks", "place": "island"}'),
#  (3157826237, 49.8830876, -6.3411727, '{"name": "Horse Point", "name:kw": "Penn Margh", "place": "locality", "source:name:kw": "https://commons.wikimedia.org/wiki/File:Cornish-placenames-20220817.pdf"}'),
#  (380754502, 49.8839462, -6.34193, '{"ele": "15", "natural": "peak"}'),
# ...

# %%
# %sql USE `ads_2024`;
# %sql DESCRIBE osm_nodes;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 4 rows affected.
# [('id', 'bigint(20)', 'YES', '', None, ''),
#  ('lat', 'double', 'YES', 'MUL', None, ''),
#  ('lon', 'double', 'YES', '', None, ''),
#  ('tags', 'text', 'YES', '', None, '')]

# %% [markdown]
# Write a short paragraph summarising what you did in the Access stage.

# %% [markdown]
# ## Assess

# %%
def string_to_dict(tag_string):
    tag_string = tag_string[1:-1]
    if pd.isna(tag_string):
        return None
    try:
        return {k[1:-1]: v[1:-1] for k, v in (item.split(': ') for item in tag_string.split(', '))}
    except ValueError:
        return None

# %%
tags = {
    "amenity": True,
    "buildings": True,
    "historic": True,
    "leisure": True,
    "shop": True,
    "tourism": True,
    "religion": True,
    "memorial": True
}

# %%
# High student population
place_name = "Cambridge"
latitude = 52.1951
longitude = 0.1313

# %%
def get_pois(latitude, longitude):
  box = 0.02
  south, north = latitude-box, latitude+box
  west, east = longitude-box, longitude+box
  pois = %sql SELECT DISTINCT * FROM osm_nodes WHERE lat between :south AND :north AND lon BETWEEN :west AND :east;
  pois_df = pois.DataFrame()
  return pois_df

# %%
cambridge_pois = get_pois(latitude, longitude)
cambridge_pois
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 12623 rows affected.
#                id        lat       lon  \
# 0      5600448343  52.175108  0.139161
# 1      1988397758  52.175117  0.115048
# 2      2246580773  52.175121  0.119167
# 3      1643255273  52.175128  0.139586
# 4      7028438785  52.175132  0.139718
# ...           ...        ...       ...
# 12618  1918608960  52.215083  0.128127
# 12619  1870125985  52.215091  0.123689
# 12620  1944501618  52.215095  0.129916
# 12621  1870056838  52.215096  0.120088
# 12622  1578035663  52.215100  0.113690
#
#                                                     tags
# 0      {"amenity": "bicycle_parking", "bicycle_parkin...
# 1      {"addr:city": "Cambridge", "addr:housenumber":...
# 2                  {"natural": "tree", "source": "Bing"}
# 3                                   {"amenity": "bench"}
# 4      {"amenity": "cafe", "brand": "Starbucks", "bra...
# ...

# %%
def tags_counter(pois_df):
  counter = {}
  features = pois_df['tags']

  for i in range(len(features)):
    feature = string_to_dict(features[i])
    try:
      for k, v in feature.items():
        if k not in counter:
          counter[k] = {}
        if v not in counter[k]:
          counter[k][v] = 0
        counter[k][v] += 1
    except:
      continue

  return counter

# %%
cambridge_counter = tags_counter(cambridge_pois)
print(cambridge_counter)
# Out:
# {'amenity': {'bicycle_parking': 661, 'bench': 490, 'cafe': 100, 'atm': 22, 'parking': 87, 'fast_food': 66, 'post_box': 66, 'doctors': 8, 'waste_basket': 121, 'recycling': 40, 'grit_bin': 3, 'parking_space': 8, 'bicycle_repair_station': 6, 'library': 1, 'clock': 9, 'kindergarten': 2, 'telephone': 40, 'post_office': 8, 'restaurant': 110, 'public_bookcase': 8, 'pharmacy': 6, 'pub': 14, 'dentist': 14, 'parking_entrance': 11, 'veterinary': 1, 'parcel_locker': 3, 'cinema': 3, 'motorcycle_parking': 13, 'place_of_worship': 2, 'community_centre': 2, 'car_rental': 2, 'toilets': 19, 'shelter': 4, 'vending_machine': 3, 'drinking_water': 4, 'college': 2, 'taxi': 3, 'photo_booth': 3, 'childcare': 4, 'bank': 10, 'bbq': 1, 'money_transfer': 1, 'charging_station': 13, 'bicycle_rental': 1, 'fountain': 7, 'car_sharing': 2, 'language_school': 3, 'wheelchair_lift': 4, 'boat_rental': 2, 'bar': 10, 'theatre': 2, 'bus_station': 3, 'table': 2, 'hand_pump': 1, 'nightclub': 4, 'courthouse': 1, 'ice_cream': 3, 
# ...

# %%
def features_over_n(counter, n):
    top_feat = {}
    for k, v in counter.items():
      v_keys = list(v.keys())
      for key in v_keys:
        if v[key] > n:
          if k not in top_feat:
            top_feat[k] = []
          top_feat[k].append((key, v[key]))

    return top_feat

# %%
cambridge_feat_100 = features_over_n(cambridge_counter, 100)
cambridge_feat_100
# Out:
# {'amenity': [('bicycle_parking', 661),
#   ('bench', 490),
#   ('waste_basket', 121),
#   ('restaurant', 110)],
#  'bicycle_parking': [('stands', 500)],
#  'covered': [('yes', 129), ('no', 388)],
#  'addr:city': [('Cambridge', 4395)],
#  'addr:housenumber': [('1', 199)],
#  'addr:street': [('Mill Road', 184)],
#  'source': [('survey', 2568), ('Bing', 264), ('naptan_import', 158)],
#  'natural': [('tree', 1105)],
#  'backrest': [('yes', 283)],
#  'material': [('wood', 158)],
#  'entrance': [('main', 652), ('yes', 1274), ('secondary', 210), ('home', 567)],
#  'crossing': [('unmarked', 101), ('traffic_signals', 102)],
#  'crossing:island': [('no', 195)],
#  'highway': [('crossing', 323), ('bus_stop', 184)],
#  'tactile_paving': [('yes', 245), ('no', 184)],
#  'operator': [('University of Cambridge', 383),
#   ('Trinity College (University of Cambridge)', 113),
#   ("St John's College (University of Cambridge)", 117)],
#  'kerb': [('lowered', 148)],
#  'access': [('private', 607)],
# ...

# %%
# wakefield, big city with no uni campus
place_name = "Wakefield"
latitude = 53.682258
longitude = -1.499935

# %%
wakefield_pois = get_pois(latitude, longitude)
wakefield_counter = tags_counter(wakefield_pois)
print(wakefield_counter)
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 5124 rows affected.
# ...

# %%
wakefield_over30 = features_over_n(wakefield_counter, 30)
wakefield_over30
# Out:
# {'created_by': [('JOSM', 1325)],
#  'highway': [('bus_stop', 243), ('traffic_signals', 219), ('crossing', 331)],
#  'naptan:Bearing': [('S', 44), ('N', 38)],
#  'naptan:PlusbusZoneRef': [('LEEDS', 257)],
#  'naptan:verified': [('yes', 207), ('no', 52)],
#  'source': [('naptan_import', 259),
#   ('survey', 133),
#   ('OS_OpenData_StreetView', 1118)],
#  'timetable': [('yes', 101)],
#  'generator:method': [('photovoltaic', 62)],
#  'generator:output:electricity': [('yes', 31), ('small_installation', 31)],
#  'generator:source': [('solar', 62)],
#  'generator:type': [('solar_photovoltaic_panel', 62)],
#  'power': [('generator', 63), ('pole', 160)],
#  'addr:city': [('Wakefield', 458)],
#  'addr:street': [('Westgate', 66), ('Northgate', 48)],
#  'barrier': [('gate', 179), ('bollard', 279)],
#  'bus': [('yes', 227)],
#  'public_transport': [('platform', 227)],
#  'shelter': [('yes', 80), ('no', 49)],
#  'natural': [('tree', 77)],
# ...

# %%
box = 0.02
south, north = latitude-box, latitude+box
west, east = longitude-box, longitude+box

graph = ox.graph_from_bbox((north, south, east, west))

nodes, edges = ox.graph_to_gdfs(graph)
area = ox.geocode_to_gdf(place_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/osmnx/_overpass.py:265: UserWarning: This area is 12,988 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-413-7ce8a74b088c> in <cell line: 5>()
#       3 west, east = longitude-box, longitude+box
#       4
# ----> 5 graph = ox.graph_from_bbox((north, south, east, west))
#       6
#       7 nodes, edges = ox.graph_to_gdfs(graph)
#
# /usr/local/lib/python3.10/dist-packages/osmnx/graph.py in graph_from_bbox(bbox, network_type, simplify, retain_all, truncate_by_edge, custom_filter)
#     100
#     101     # create graph using this polygon geometry
# --> 102     G = graph_from_polygon(
# ...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# Plot the footprint
area.plot(ax=ax, facecolor="white")

# Plot street edges
edges.plot(ax=ax, linewidth=1, edgecolor="dimgray")

ax.set_xlim([west, east])
ax.set_ylim([south, north])
ax.set_xlabel("longitude")
ax.set_ylabel("latitude")

# %% [markdown]
# Write a short paragraph summarising what you did in the Assess stage.

# %%
# TODO: your answer here

# %% [markdown]
# ## Address

# %%
keys = ["amenity", "shop", "leisure"]
specific_keys = []

# %%
data = {'OA21CD': []}
for k in keys:
  data[k] = []
for k1, k2 in specific_keys:
  data[k1 + "=" + k2] = []
feature_count = pd.DataFrame(data)
feature_count
# Out:
# Empty DataFrame
# Columns: [OA21CD, amenity, shop, leisure]
# Index: []

# %%
from collections import Counter

def count_keys(tags, keys):
    return Counter({key: tags.get(key, None) is not None for key in keys})

def count_specific_keys(tags, specific_keys):
    tag_counter = Counter()

    for tag in specific_keys:
        key, value = tag
        if tags.get(key) == value:
            tag_counter[f'{key}={value}'] = 1
        else:
            tag_counter[f'{key}={value}'] = 0

    return tag_counter

# %%
from copy import Error
def extract_tag_counts(tags_df, keys, specific_keys):
  try:
    tags_df["tags"] = tags_df["tags"].apply(lambda x: string_to_dict(x))
    tags_df = tags_df.dropna()
  except:
    raise Error

  key_counts = tags_df['tags'].apply(lambda x: count_keys(x, keys))
  specific_key_counts = tags_df['tags'].apply(lambda x: count_specific_keys(x, specific_keys))
  total_key_counts = sum(key_counts, Counter())
  total_specific_key_counts = sum(specific_key_counts, Counter())

  key_count_df = pd.DataFrame(total_key_counts.items(), columns=['Key', 'Count'])
  specific_key_count_df = pd.DataFrame(total_specific_key_counts.items(), columns=['Key', 'Count'])
  count_df = pd.concat([key_count_df, specific_key_count_df], axis=0, ignore_index=True)

  for k in keys:
    if k not in list(count_df["Key"]):
      count_df.loc[len(count_df)] = [k, 0]
  for k1, k2 in specific_keys:
    col = k1 + "=" + k2
    if col not in list(count_df["Key"]):
      count_df.loc[len(count_df)] = [col, 0]

  return count_df

def change_count_df_format(count_df, key):
  count_df.loc[len(count_df)] = ["OA21CD", key]
  df2 = pd.DataFrame(columns=count_df["Key"])
  df2.loc[0] = count_df['Count'].values

  return df2

# %%
# %sql USE `ads_2024`;
training_set_size = 50
train_oas = %sql SELECT * FROM oa_data ORDER BY RAND() LIMIT :training_set_size;
train_oas_df = train_oas.DataFrame()
train_oas_df
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 50 rows affected.
#      index     FID     OA21CD   LSOA21CD                           LSOA21NM  \
# 0    90599   90600  E00095890  E01018983                      Cornwall 057D
# 1   148911  148912  E00157124  E01030819                     Tandridge 011D
# 2   183010  183011  W00004556  W01000854                       Swansea 022B
# 3   145111  145112  E00153175  E01030055                   Mid Suffolk 002C
# 4    70508   70509  E00074744  E01014795                North Somerset 001C
# 5    40349   40350  E00042885  E01008451           Newcastle upon Tyne 016C
# 6    20418   20419  E00021808  E01004336                Waltham Forest 026A
# 7   184700  184701  W00006325  W01001963             Rhondda Cynon Taf 014H
# ...

# %%
for i in range(training_set_size):
  lat = train_oas_df["LAT"][i]
  lon = train_oas_df["LON"][i]
  start_lat, end_lat = lat-1/111, lat+1/111
  start_lon, end_lon = lon-1/111, lon+1/111

  tags = %sql SELECT id, tags FROM osm_nodes WHERE lat between :start_lat AND :end_lat AND lon BETWEEN :start_lon AND :end_lon;
  try:
    tags_df = tags.DataFrame()
  except:
    continue
  tags_df["amount_of_tags"] = tags_df["tags"].apply(lambda x: len(x))
  total_tags = sum(tags_df["amount_of_tags"])/100

  try:
    count_df = extract_tag_counts(tags_df, keys, specific_keys)
  except:
    continue
  count_df["Count"] = count_df["Count"].apply(lambda x: x/total_tags)
  row_features_df = change_count_df_format(count_df, train_oas_df["OA21CD"][i])
  feature_count = pd.concat([feature_count, row_features_df], ignore_index=True)
  print("added " + str(i))
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 1859 rows affected.
# added 0
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 91 rows affected.
# added 1
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 719 rows affected.
# added 2
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 32 rows affected.
# added 3
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 669 rows affected.
# added 4
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 1116 rows affected.
# added 5
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 7224 rows affected.
# added 6
# ...

# %%
feature_count
# Out:
#        OA21CD   amenity      shop   leisure
# 0   E00095890  0.084794  0.009422       0.0
# 1   E00157124  0.064746  0.032373       0.0
# 2   W00004556  0.076137  0.039591       0.0
# 3   E00153175   0.11534       0.0       0.0
# 4   E00074744  0.295049       0.0  0.030399
# 5   E00042885  0.036591  0.011435  0.001143
# 6   E00021808  0.107547  0.033044  0.006425
# 7   W00006325  0.111917  0.007718       0.0
# 8   E00071607  0.019451  0.012968  0.032419
# 9   E00022243  0.148057  0.039836  0.019254
# 10  E00118265  0.042808       0.0       0.0
# 11  E00106577   0.05338  0.004853       0.0
# 12  E00156730  0.130726  0.060547       0.0
# 13  E00169091  0.038845  0.001494  0.029881
# 14  E00112745  0.043754  0.032816       0.0
# 15  W00005642  0.159021  0.013353  0.015781
# 16  E00094125  0.065941       0.0       0.0
# 17  E00042823  0.171305  0.143609  0.012309
# 18  E00130524  0.122602  0.007212       0.0
# 19  E00164181  0.068763  0.011959  0.005979
# ...

# %%
# predicting student
student_oa_codes = set(feature_count["OA21CD"])

# %sql USE `ads_2024`;
student_oa_info = %sql SELECT OA21CD, L1L3, L4L6, L7, L8L9, L10L11, L12, L13, L14, L15 FROM statistics_data WHERE OA21CD IN :student_oa_codes;
student_oa_info_df = student_oa_info.DataFrame()

student_oa_info_codes = student_oa_info_df["OA21CD"]
student_oa_info_df = student_oa_info_df.drop(columns=["OA21CD"])
student_oa_info_df = student_oa_info_df.apply(lambda row: row / row.sum(), axis=1)
student_oa_info_df["OA21CD"] = student_oa_info_codes

student_oa_info_df = student_oa_info_df.drop(columns=["L1L3", "L4L6", "L7", "L8L9", "L10L11", "L12", "L13", "L14"])
student_oa_info_df
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 50 rows affected.
#          L15     OA21CD
# 0   0.031128  E00015413
# 1   0.127869  E00021808
# 2   0.055970  E00022243
# 3   0.045249  E00033785
# 4   0.038278  E00037876
# 5   0.078603  E00039489
# 6   0.091703  E00042823
# 7   0.089552  E00042885
# 8   0.044828  E00043551
# 9   0.091324  E00055296
# 10  0.051587  E00059241
# 11  0.037453  E00059952
# 12  0.034884  E00065782
# 13  0.058974  E00071607
# 14  0.257009  E00072577
# 15  0.055556  E00074744
# 16  0.037975  E00075378
# 17  0.049123  E00080013
# 18  0.070632  E00084668
# 19  0.050228  E00094125
# 20  0.041534  E00095890
# 21  0.026316  E00103726
# 22  0.040404  E00106577
# 23  0.057692  E00109832
# 24  0.030973  E00112745
# 25  0.052045  E00118031
# 26  0.051852  E00118265
# ...

# %%
# predicting highest qualification: L4 - degree level qualification
qualification_oa_codes = set(feature_count["OA21CD"])

# %sql USE `ads_2024`;
qualification_oa_info = %sql SELECT OA21CD, L4, total FROM qualification_data WHERE OA21CD IN :qualification_oa_codes;
qualification_oa_info_df = qualification_oa_info.DataFrame()
qualification_oa_info_df["L4"] = qualification_oa_info_df["L4"] / qualification_oa_info_df["total"]
qualification_oa_info_df = qualification_oa_info_df.drop(columns=["total"])

qualification_oa_info_df
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 50 rows affected.
#        OA21CD        L4
# 0   E00015413  0.575875
# 1   E00021808  0.418605
# 2   E00022243  0.498141
# 3   E00033785  0.265766
# 4   E00037876  0.128571
# 5   E00039489  0.178261
# 6   E00042823  0.166667
# 7   E00042885  0.331658
# 8   E00043551  0.327586
# 9   E00055296  0.268182
# 10  E00059241  0.162698
# 11  E00059952  0.310606
# 12  E00065782  0.222222
# 13  E00071607  0.484772
# 14  E00072577  0.452830
# 15  E00074744  0.345455
# 16  E00075378  0.317797
# 17  E00080013  0.319298
# 18  E00084668  0.436567
# 19  E00094125  0.364865
# 20  E00095890  0.296178
# 21  E00103726  0.500000
# 22  E00106577  0.286432
# 23  E00109832  0.191083
# 24  E00112745  0.203540
# 25  E00118031  0.591760
# 26  E00118265  0.409594
# ...

# %%
df_combined = feature_count.merge(student_oa_info_df, how='inner', on='OA21CD')
df_combined = df_combined.merge(qualification_oa_info_df, how='inner', on='OA21CD')
df_combined
# Out:
#        OA21CD   amenity      shop   leisure       L15        L4
# 0   E00095890  0.084794  0.009422       0.0  0.041534  0.296178
# 1   E00157124  0.064746  0.032373       0.0  0.069697  0.314199
# 2   W00004556  0.076137  0.039591       0.0  0.089595  0.472303
# 3   E00153175   0.11534       0.0       0.0  0.063025  0.354298
# 4   E00074744  0.295049       0.0  0.030399  0.055556  0.345455
# 5   E00042885  0.036591  0.011435  0.001143  0.089552  0.331658
# 6   E00021808  0.107547  0.033044  0.006425  0.127869  0.418605
# 7   W00006325  0.111917  0.007718       0.0  0.062718  0.203509
# 8   E00071607  0.019451  0.012968  0.032419  0.058974  0.484772
# 9   E00022243  0.148057  0.039836  0.019254  0.055970  0.498141
# 10  E00118265  0.042808       0.0       0.0  0.051852  0.409594
# 11  E00106577   0.05338  0.004853       0.0  0.040404  0.286432
# 12  E00156730  0.130726  0.060547       0.0  0.092063  0.501587
# 13  E00169091  0.038845  0.001494  0.029881  0.029412  0.470339
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
x = df_combined[keys + [k1 + '=' + k2 for (k1, k2) in specific_keys]]
student_y = df_combined['L15']

x = x.apply(pd.to_numeric, errors='coerce')
student_y = pd.to_numeric(student_y, errors='coerce')

x = x.dropna()
student_y = student_y.dropna()
x = sm.add_constant(x)

student_model = sm.OLS(student_y, x).fit()
student_y_pred = student_model.predict(x)

fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(111)
ax.scatter(student_y, student_y_pred, zorder=2)

plt.tight_layout()
plt.show()

# %%
print(student_model.summary())

student_correlation = np.corrcoef(student_y, student_y_pred)[0, 1]
print("Correlation coefficient is", student_correlation)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    L15   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.9525
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):              0.423
# Time:                        02:51:01   Log-Likelihood:                 49.940
# No. Observations:                  50   AIC:                            -91.88
# Df Residuals:                      46   BIC:                            -84.23
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0488      0.023      2.136      0.038       0.003       0.095
# ...

# %%
x = df_combined[keys + [k1 + '=' + k2 for (k1, k2) in specific_keys]]
qualification_y = df_combined['L4']

x = x.apply(pd.to_numeric, errors='coerce')
qualification_y = pd.to_numeric(qualification_y, errors='coerce')

x = x.dropna()
qualification_y = qualification_y.dropna()

x = sm.add_constant(x)

qualification_model = sm.OLS(qualification_y, x).fit()
qualification_y_pred = qualification_model.predict(x)

fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(111)
ax.scatter(qualification_y, qualification_y_pred, zorder=2)

plt.tight_layout()
plt.show()

# %%
print(qualification_model.summary())

qualification_correlation = np.corrcoef(qualification_y, qualification_y_pred)[0, 1]
print("Correlation coefficient is", qualification_correlation)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     L4   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.9258
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):              0.436
# Time:                        02:51:14   Log-Likelihood:                 35.808
# No. Observations:                  50   AIC:                            -63.62
# Df Residuals:                      46   BIC:                            -55.97
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3171      0.030     10.457      0.000       0.256       0.378
# ...

# %%
def estimate_students(latitude: float, longitude: float, keys, specific_keys) -> float:
    data = {'OA21CD': []}
    for k in keys:
      data[k] = []
    for k1, k2 in specific_keys:
      data[k1 + "=" + k2] = []
    feature_count = pd.DataFrame(data)

    start_lat, end_lat = latitude-1/111, latitude+1/111
    start_lon, end_lon = longitude-1/111, longitude+1/111

    tags = %sql SELECT id, tags FROM osm_nodes WHERE lat between :start_lat AND :end_lat AND lon BETWEEN :start_lon AND :end_lon;
    tags_df = tags.DataFrame()
    tags_df["amount_of_tags"] = tags_df["tags"].apply(lambda x: len(x))
    total_tags = sum(tags_df["amount_of_tags"])/100

    try:
      count_df = extract_tag_counts(tags_df, keys, specific_keys)
    except:
      print("There are no features that have been trained on")
      return -1.0
    count_df["Count"] = count_df["Count"].apply(lambda x: x/total_tags)
    row_features_df = change_count_df_format(count_df, "temp")
    feature_count = pd.concat([feature_count, row_features_df], ignore_index=True)
    feature_count = feature_count.drop(columns=["OA21CD"])

    x = feature_count[keys + [k1 + '=' + k2 for (k1, k2) in specific_keys]]
    x["const"] = 1
    y_pred = student_model.predict(x)

    return y_pred[0]


def estimate_something(latitude: float, longitude: float, keys, specific_keys) -> float:
    data = {'OA21CD': []}
    for k in keys:
      data[k] = []
    for k1, k2 in specific_keys:
      data[k1 + "=" + k2] = []
    feature_count = pd.DataFrame(data)

    start_lat, end_lat = latitude-1/111, latitude+1/111
    start_lon, end_lon = longitude-1/111, longitude+1/111

    tags = %sql SELECT id, tags FROM osm_nodes WHERE lat between :start_lat AND :end_lat AND lon BETWEEN :start_lon AND :end_lon;
    tags_df = tags.DataFrame()
    tags_df["amount_of_tags"] = tags_df["tags"].apply(lambda x: len(x))
    total_tags = sum(tags_df["amount_of_tags"])/100

    try:
      count_df = extract_tag_counts(tags_df, keys, specific_keys)
    except:
      print("There are no features that have been trained on")
      return -1.0
    count_df["Count"] = count_df["Count"].apply(lambda x: x/total_tags)
    row_features_df = change_count_df_format(count_df, "temp")
    feature_count = pd.concat([feature_count, row_features_df], ignore_index=True)
    feature_count = feature_count.drop(columns=["OA21CD"])

    x = feature_count[keys + [k1 + '=' + k2 for (k1, k2) in specific_keys]]
    x["const"] = 1
    y_pred = qualification_model.predict(x)

    return y_pred[0]

# %%
estimate_students(52.201549, 0.127536, keys, specific_keys)
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 4412 rows affected.
# -1.3768299353603688

# %% [markdown]
# Write a short paragraph summarising what you did in the Address stage.

# %%
# TODO: your answer here

# %% [markdown]
# ## Discussion

# %% [markdown]
# #### Story and structure

# %%
# Marks awarded for inline explanation and structure, no need for answers here. Go over your notebook to make sure you explain what you did and why.

# %% [markdown]
# #### Design decisions

# %%
# TODO: your answer here

# %% [markdown]
# #### Comparison

# %%
# TODO: your answer here

# %% [markdown]
# #### Reusability

# %%
# TODO: your answer here

# %% [markdown]
# # Task 2: miniproject (13 marks)

# %% [markdown]
# We expect your miniproject to be more advanced than the example project, and that's why we allocated more marks to it. The first 7 marks will be allocated similarly to Task 1.
#
# 6 remaining points are *bonus* - they will be allocated for going far beyond what you did in Task 1, either in data access, assess, address or story.

# %% [markdown]
# #### Choosing your topic
#
# You are given a lot of flexibility in choosing a miniproject topic.
#
# Some hints:
# - Your project should be based on the Census, Price Paid, OSM and Election datasets.
# - It's a good idea to pick something that you are interested in.
# - Bear in mind there are no marks dedicated to your overall prediction accuracy, so there is no advantage to picking 'easy' topics. It is perfectly ok to not reach significant predictive power, as long as you followed the proper process.
#
# Some guidelines:
# - Do not make a miniproject that furthers discriminatory rhetoric. In general, avoid topics that could be insensitive. If in doubt, message Radzim Sendyka (and *cc* Christian Cabrera) to discuss if this applies to your idea.
# - Please avoid any projects that would require approval from the ethics comittee.
# - Pick the scope of your projects that will allow you to show your skills. Some projects might not be challenging enough while others might be hard to make any progress in. Don't be scared to report negative results.
#
# Please email Radzim Sendyka (and *cc* Christian Cabrera) with your project idea when you begin working on it, so we can let you know about any potential concerns (eg. potentially insensive, too off-topic, too simple, too complex) as soon as we can. You can change the topic up to the submission deadline, but let us know again in cases of major changes.

# %% [markdown]
# Most of the advice from Task 1 still applies, particularly around using an online relational database, structuring your notebook, fynesse, access-assess-address, data readiness levels, hints.

# %% [markdown]
# Sources you may want to include in your data include:
#
#   - UK Census Data
#     - UK Census 2021 data [here](https://www.ons.gov.uk/search?topics=9731,6646,3845,9497,4262,4128,7755,4994,6885,9724,7367&filter=datasets) or [here](https://www.nomisweb.co.uk/sources/census_2021_bulk).
#     - Historical Census data [here](https://www.ons.gov.uk/census/historiccensusdata).
#     - Geographic coordinates of Census Output Areas [here](https://www.data.gov.uk/dataset/4d4e021d-fe98-4a0e-88e2-3ead84538537/output-areas-december-2021-boundaries-ew-bgc-v2).
#   - Spatial data
#     - You should already have a connection to OpenStreetMaps.
#     - You might want to also download the entire map for England (or more) [here](https://download.openstreetmap.fr/extracts/) or [here](https://wiki.openstreetmap.org/wiki/Planet.osm).
#   - Election data
#     - Recent Election Results data [here](https://commonslibrary.parliament.uk/research-briefings/cbp-10009/)
#     - Historical Election Results data [here](https://commonslibrary.parliament.uk/research-briefings/cbp-8647/#fullreport).
#     - Lookup reference between Output Areas and Parliamentary Constituencies [here](https://geoportal.statistics.gov.uk/datasets/5968b5b2c0f14dd29ba277beaae6dec3_0/explore).
#   - Price Paid Data
#     - You should have this data already in your database.
#   - OSM
#     - You should know how to access this data from previous practicals.

# %% [markdown]
# Example ideas:
#
# - Are areas correlated in terms of census results? If so, find the areas that are leading change, and the ones that are following.
# - Which historical census variables used to predict election results in the past, but don't seem related anymore?
# - Census results are only updated once a decade, but new roads and houses are built every year. Can census results, for example those relating to travel, be predicted from basic map information, such as street networks?
# - Building new houses is our best way of tackling the housing crisis. Use the information on new builds in the house prices dataset to explore what factors drive new developments, and make predictions for where the next houses will be built.
# - House styles differ a lot between regions and inhabitants. Can you make any predictions about the house or area simply from looking at it's geometric shape and orientation?
#
# Note that the ideas are just a starting point question. You should include more in-depth investigations into the data, validate your findings where applicable, and prepare visualisations.

# %% [markdown]
# ## Title and description

# %%
# TODO: title your miniproject

# %%
# TODO: provide a very brief description of the goals of your miniproject

# %% [markdown]
# ## TODO: Your Project Goes Here

# %% [markdown]
# #Access

# %%
# %pip install pymysql
# %pip install sqlalchemy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 2.0 MB/s eta 0:00:00
# ...

# %%
# %load_ext sql
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
import yaml

# %%
with open("credentials.yaml") as file:
  credentials = yaml.safe_load(file)
username = credentials["username"]
password = credentials["password"]
url = credentials["url"]
port = credentials["port"]

# %%
# %sql mariadb+pymysql://$username:$password@$url?local_infile=1
# %sql SHOW databases
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 7 rows affected.
# [('ads_2024',),
#  ('information_schema',),
#  ('innodb',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('tmp',)]

# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine(f'mysql+pymysql://{username}:{password}@{url}/{"ads_2024"}')

# %%
# %sql USE `ads_2024`;
# %sql SHOW TABLES;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 9 rows affected.
# [('election_data',),
#  ('oa_data',),
#  ('osm_nodes',),
#  ('postcode_data',),
#  ('postcode_oa_lookup',),
#  ('pp_data',),
#  ('prices_coordinates_data',),
#  ('qualification_data',),
#  ('statistics_data',)]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
election_df = pd.read_csv("election.csv")
election_df_columns = []
for col in election_df.columns:
  new_col = col.replace(" ", "")
  election_df_columns.append(new_col)
election_df.columns = election_df_columns
election_df = election_df.drop(columns=['Countyname',
       'ElectoralCommissionpartyID', 'MNISpartyID',
       'ElectoralCommissionadjunctpartyID', 'Candidatefirstname',
       'Candidatesurname', 'Candidategender', 'SittingMP', 'FormerMP',
       'MemberMNISID', 'Votes', 'Change', 'DCPersonID'])
election_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-99def34cd5e0> in <cell line: 1>()
# ----> 1 election_df = pd.read_csv("election.csv")
#       2 election_df_columns = []
#       3 for col in election_df.columns:
#       4   new_col = col.replace(" ", "")
#       5   election_df_columns.append(new_col)
#
# ...

# %%
election_df = election_df.loc[election_df.groupby("ONSID")["Share"].idxmax()]
election_df
# Out:
#           ONSID ONSregionID          Constituencyname     Regionname  \
# 42    E14001063   E12000008                 Aldershot     South East
# 47    E14001064   E12000005       Aldridge-Brownhills  West Midlands
# 62    E14001065   E12000002  Altrincham and Sale West     North West
# 74    E14001066   E12000004              Amber Valley  East Midlands
# 99    E14001067   E12000008   Arundel and South Downs     South East
# ...         ...         ...                       ...            ...
# 3986  W07000108   W92000004              Swansea West          Wales
# 4093  W07000109   W92000004                   Torfaen          Wales
# 4158  W07000110   W92000004         Vale of Glamorgan          Wales
# 4459  W07000111   W92000004                   Wrexham          Wales
# 4496  W07000112   W92000004                  Ynys Môn          Wales
#
#      Countryname Constituencytype     Partyname Partyabbreviation     Share
# ...

# %%
oa_con_df = pd.read_csv("oa_to_con.csv")
oa_con_df = oa_con_df.drop(columns=["PCON25NMW", "LAD21CD", "LAD21NM", "ObjectId"])
oa_con_df.columns = ['OA21CD', 'ONSID', 'Name']
oa_con_df
# Out:
# <ipython-input-29-0177e388beec>:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   oa_con_df = pd.read_csv("oa_to_con.csv")
#            OA21CD      ONSID              Name
# 0       E00000337  E14001073           Barking
# 1       E00000338  E14001073           Barking
# 2       E00000340  E14001073           Barking
# 3       E00000341  E14001073           Barking
# 4       E00000342  E14001073           Barking
# ...           ...        ...               ...
# 188875  W00010693  W07000083  Bangor Aberconwy
# 188876  W00010694  W07000087       Caerfyrddin
# 188877  W00010695  W07000098          Llanelli
# 188878  W00010696  W07000098          Llanelli
# 188879  W00010697  W07000098          Llanelli
#
# [188880 rows x 3 columns]

# %%
election_oa_df = election_df.merge(oa_con_df, how="inner", on="ONSID")
election_oa_df = election_oa_df.drop_duplicates()
election_oa_df
# Out:
#             ONSID ONSregionID Constituencyname  Regionname Countryname  \
# 0       E14001063   E12000008        Aldershot  South East     England
# 1       E14001063   E12000008        Aldershot  South East     England
# 2       E14001063   E12000008        Aldershot  South East     England
# 3       E14001063   E12000008        Aldershot  South East     England
# 4       E14001063   E12000008        Aldershot  South East     England
# ...           ...         ...              ...         ...         ...
# 188875  W07000112   W92000004         Ynys Môn       Wales       Wales
# 188876  W07000112   W92000004         Ynys Môn       Wales       Wales
# 188877  W07000112   W92000004         Ynys Môn       Wales       Wales
# 188878  W07000112   W92000004         Ynys Môn       Wales       Wales
# 188879  W07000112   W92000004         Ynys Môn       Wales       Wales
#
#        Constituencytype    Partyname Partyabbreviation     Share     OA21CD  \
# ...

# %%
election_oa_df.to_sql('election_data', con=engine, if_exists='replace', index=False)
# Out:
# 188880

# %%
# %sql USE `ads_2024`;
# %sql SELECT * FROM election_data LIMIT 2;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 2 rows affected.
# [('E14001063', 'E12000008', 'Aldershot', 'South East', 'England', 'Borough', 'Labour', 'Lab', 0.407136, 'E00116100', 'Aldershot'),
#  ('E14001063', 'E12000008', 'Aldershot', 'South East', 'England', 'Borough', 'Labour', 'Lab', 0.407136, 'E00116101', 'Aldershot')]

# %%
# %sql USE `ads_2024`;
# %sql SELECT DISTINCT Regionname FROM election_data;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 10 rows affected.
# [('South East',),
#  ('West Midlands',),
#  ('North West',),
#  ('East Midlands',),
#  ('London',),
#  ('Yorkshire and The Humber',),
#  ('East of England',),
#  ('South West',),
#  ('North East',),
#  ('Wales',)]

# %%
# %sql USE `ads_2024`;
# %sql CREATE INDEX idx_election_ONS ON election_data(ONSID);
# %sql CREATE INDEX idx_election_region ON election_data(Regionname);
# %sql CREATE INDEX idx_election_OA ON election_data(OA21CD);
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# []

# %%
pcd_con_path = "/content/drive/My Drive/pcd-con.csv"
pcd_con_df = pd.read_csv(pcd_con_path)
pcd_con_df = pcd_con_df[["pcd7", "oa21cd"]]
pcd_con_df = pcd_con_df.drop_duplicates()
pcd_con_df.head()
# Out:
# <ipython-input-124-573ab482a00a>:2: DtypeWarning: Columns (8,10,13,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   pcd_con_df = pd.read_csv(pcd_con_path)
#       pcd7     oa21cd
# 0  AB1 0AA  S00090303
# 1  AB1 0AB  S00090303
# 2  AB1 0AD  S00090399
# 3  AB1 0AE  S00091322
# 4  AB1 0AF  S00090299

# %%
pcd_con_df["pcd7"] = pcd_con_df["pcd7"].apply(lambda x: x[:len(x)//2+1] + ' ' + x[len(x)//2+1:] if ' ' not in x else x)
pcd_con_df["pcd7"] = pcd_con_df["pcd7"].apply(lambda x: x.replace("  ", " "))

# %%
pcd_con_df.to_sql('postcode_oa_lookup', con=engine, if_exists='replace', index=False)
# Out:
# 2697530

# %%
# %sql USE `ads_2024`;
# %sql SELECT * FROM postcode_oa_lookup LIMIT 2;
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 2 rows affected.
# [('AB1 0AA', 'S00090303'), ('AB1 0AB', 'S00090303')]

# %%
# %sql USE `ads_2024`;
# %sql CREATE INDEX idx_lookup_oa ON postcode_oa_lookup(oa21cd)
# %sql CREATE INDEX idx_lookup_postcode ON postcode_oa_lookup(pcd7)
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# []

# %%
# %sql USE `ads_2024`;
# %sql CREATE INDEX idx_prices_postcode ON prices_coordinates_data(postcode)
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# []

# %%
rural_urban_df = pd.read_csv("rural-urban.csv")
# {'A1', 'B1', 'C1', 'C2', 'D1', 'D2', 'E1', 'E2', 'F1', 'F2'}
urban_tags = ["A1", "B1", "C1", "C2"]
rural_tags = ["D1", "D2", "E1", "E2", "F1", "F2"]

# %%
oa11_oa21_lookup = pd.read_csv("oa11cd-oa21cd.csv")
oa11_oa21_lookup = oa11_oa21_lookup[["OA11CD", "OA21CD"]]
# Out:
# <ipython-input-79-d62a75b32d05>:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   oa11_oa21_lookup = pd.read_csv("oa11cd-oa21cd.csv")

# %%
rural_urban_df_final = rural_urban_df.merge(oa11_oa21_lookup, on="OA11CD", how="inner")
rural_urban_df_final["Urban"] = rural_urban_df_final["RUC11CD"].apply(lambda x: True if x in urban_tags else False)
rural_urban_df_final = rural_urban_df_final[["OA21CD", "Urban"]]
rural_urban_df_final.columns = ["oa21cd", "urban"]
rural_urban_df_final
# Out:
#            oa21cd  urban
# 0       E00000001   True
# 1       E00000003   True
# 2       E00000005   True
# 3       E00000007   True
# 4       E00000010   True
# ...           ...    ...
# 181403  W00010261   True
# 181404  W00010262   True
# 181405  W00010263   True
# 181406  W00010264  False
# 181407  W00010265   True
#
# [181408 rows x 2 columns]

# %%
rural_urban_df_final.to_sql('rural_urban_data', con=engine, if_exists='replace', index=False)
# Out:
# 181408

# %%
# %sql USE `ads_2024`;
# %sql CREATE INDEX idx_rural_urban_oa ON rural_urban_data(oa21cd)
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
# []

# %% [markdown]
# # Assess

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
def string_to_dict(tag_string):
    tag_string = tag_string[1:-1]
    if pd.isna(tag_string):
        return None
    try:
        return {k[1:-1]: v[1:-1] for k, v in (item.split(': ') for item in tag_string.split(', '))}
    except ValueError:
        return None

# %%
keys = ["amenity", "shop", "leisure"]

# %%
party_colors = {
    "Labour": "red",
    "Conservative": "blue",
    "Reform UK": "purple",
    "Liberal Democrat": "orange",
    "Labour and Co-operative": "red",
    "Independent": "gray",
    "Green": "lightgreen",
    "Speaker": "gray",
    "Plaid Cymru": "darkgreen",
}

# %%
oa_shapefile_path = "/content/drive/My Drive/uk_shapefile/ew_oa_2021.shp"
oa_gdf = gpd.read_file(oa_shapefile_path)
oa_gdf
# Out:
#                                                     label       name  \
# 0       K04000001E92000001E12000007E09000002E02000015E...  E00000530
# 1       K04000001E92000001E12000003E07000163E02005748E...  E00140439
# 2       K04000001E92000001E12000005E07000239E02006776E...  E00165348
# 3       K04000001E92000001E12000002E08000007E02001216E...  E00029302
# 4       K04000001E92000001E12000007E09000030E02000886E...  E00021425
# ...                                                   ...        ...
# 188875  K04000001E92000001E12000005E07000239E02006768E...  E00165463
# 188876  K04000001E92000001E12000004E07000171E02005847E...  E00142995
# 188877  K04000001E92000001E12000008E07000211E02006383E...  E00156198
# 188878  K04000001E92000001E12000002E07000026E02003973E...  E00096636
# 188879  K04000001E92000001E12000002E06000049E02007031E...  E00093442
#
#            oa21cd                                           geometry
# 0       E00000530  POLYGON ((550330.006 184425.592, 550333 184422...
# ...

# %%
def plot_elections(region, oa_gdf):
  if region == None:
    query = "SELECT * FROM election_data"
  else:
    query = f"SELECT * FROM election_data WHERE Regionname = '{region}'"

  election_df = pd.read_sql_query(query, con=engine)
  oa_gdf = oa_gdf.merge(election_df, left_on="oa21cd", right_on="OA21CD")

  oa_gdf["color"] = oa_gdf["Partyname"].map(party_colors)
  oa_gdf["color"] = oa_gdf["color"].fillna("gray")

  fig, ax = plt.subplots(1, 1, figsize=(12, 12))
  oa_gdf.plot(ax=ax, color=oa_gdf["color"], linewidth=0.1, edgecolor="white")

  ax.set_title("UK 2024 Election Results by Output Area", fontsize=16)
  legend_elements = [plt.Line2D([0], [0], marker="o", color=party_colors[party],
                                label=party, markersize=10) for party in party_colors]
  ax.legend(handles=legend_elements, title="Winning Party", loc="lower left")
  plt.show()

# %%
plot_elections(region=None, oa_gdf=oa_gdf)

# %%
plot_elections('London', oa_gdf)

# %%
latitude = 52.21
longitude = 0.08
radius = 10.0

# %%
def get_nearby_oas(latitude, longitude, radius_km=1.0):
  km_dg = 1/111
  min_lat, max_lat = latitude-(radius_km*km_dg), latitude+(radius_km*km_dg)
  min_lon, max_lon = longitude-(radius_km*km_dg), longitude+(radius_km*km_dg)

  # %sql USE `ads_2024`;
  oas = %sql SELECT OA21CD, LAT, LON FROM oa_data WHERE LAT BETWEEN :min_lat AND :max_lat AND LON BETWEEN :min_lon AND :max_lon;
  oas_df = oas.DataFrame()
  oas_df.columns = ["oa21cd", "lat", "lon"]
  oas_set = set(oas_df["oa21cd"])

  urban_classificaton = %sql SELECT * FROM rural_urban_data WHERE oa21cd IN :oas_set;
  urban_classificaton_df = urban_classificaton.DataFrame()
  oas_df = oas_df.merge(urban_classificaton_df, on="oa21cd", how="inner")

  return oas_df

# %%
oas = get_nearby_oas(latitude, longitude, radius)
oas
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 609 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 540 rows affected.
#         oa21cd       lat       lon  urban
# 0    E00092201  52.12267  0.162217      0
# 1    E00092212  52.12305  0.169803      0
# 2    E00092273  52.12344  0.096135      0
# 3    E00092013  52.12364  0.053808      0
# 4    E00092214  52.12434  0.162210      0
# ..         ...       ...       ...    ...
# 535  E00092000  52.29704  0.087310      0
# 536  E00092220  52.29723 -0.008590      0
# 537  E00092223  52.29732 -0.005100      0
# 538  E00092221  52.29882  0.000304      0
# 539  E00092222  52.29912 -0.005840      0
#
# [540 rows x 4 columns]

# %%
def get_pois_radius(latitude, longitude, radius_km=1.0):
  km_dg = 1/111
  min_lat, max_lat = latitude-(radius_km*km_dg), latitude+(radius_km*km_dg)
  min_lon, max_lon = longitude-(radius_km*km_dg), longitude+(radius_km*km_dg)

  pois = %sql SELECT DISTINCT * FROM osm_nodes WHERE lat between :min_lat AND :max_lat AND lon BETWEEN :min_lon AND :max_lon;
  pois_df = pois.DataFrame()
  return pois_df

# %%
pois_df = get_pois_radius(latitude, longitude, radius)
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 41737 rows affected.

# %%
from scipy.spatial import cKDTree
import numpy as np

# %%
def nearest_oa(pois_df, oa_df):
  pois_df["tags"] = pois_df["tags"].apply(string_to_dict)
  oa_gdf_points = gpd.GeoDataFrame(oa_df, geometry=gpd.points_from_xy(oa_df['lon'], oa_df['lat']), crs="EPSG:3857")
  pois_gdf = gpd.GeoDataFrame(pois_df, geometry=gpd.points_from_xy(pois_df['lon'], pois_df['lat']),crs="EPSG:3857")

  oa_coords = np.array(list(zip(oa_gdf_points.geometry.x, oa_gdf_points.geometry.y)))
  pois_coords = np.array(list(zip(pois_gdf.geometry.x, pois_gdf.geometry.y)))

  tree = cKDTree(oa_coords)
  distances, indices = tree.query(pois_coords)
  pois_gdf['nearest_oa'] = oa_gdf_points.iloc[indices]['oa21cd'].values
  pois_df_new = pois_gdf.drop(columns=['geometry'])

  return pois_df_new

# %%
pois_df = nearest_oa(pois_df, oas)

# %%
def pois_by_oa(oas, pois_df):
  oa_gdf_points = gpd.GeoDataFrame(oas, geometry=gpd.points_from_xy(oas['lon'], oas['lat']), crs="EPSG:3857")
  pois_gdf = gpd.GeoDataFrame(pois_df, geometry=gpd.points_from_xy(pois_df['lon'], pois_df['lat']),crs="EPSG:3857")

  oa_coords = np.array(list(zip(oa_gdf_points.geometry.x, oa_gdf_points.geometry.y)))
  pois_coords = np.array(list(zip(pois_gdf.geometry.x, pois_gdf.geometry.y)))

  tree = cKDTree(oa_coords)
  distances, indices = tree.query(pois_coords)
  pois_gdf['nearest_oa'] = oa_gdf_points.iloc[indices]['oa21cd'].values
  pois_df_new = pois_gdf.drop(columns=['geometry'])

  for key in keys:
    pois_df_new[key] = pois_df_new["tags"].apply(lambda tags: 1 if tags and key in tags else 0)

  osm_totals = pois_df_new.groupby("nearest_oa")[keys].sum().reset_index()
  osm_totals["total"] = osm_totals[keys].sum(axis=1)
  oas_with_counts = oas.merge(osm_totals, left_on="oa21cd" ,right_on="nearest_oa", how="left")
  oas_with_counts[keys + ["total"]] = oas_with_counts[keys + ["total"]].fillna(0)

  columns_to_normalize = keys + ["total"]
  oas_with_counts[columns_to_normalize] = oas_with_counts[columns_to_normalize].applymap(lambda x: np.log1p(x))
  oas_with_counts[columns_to_normalize] = scaler.fit_transform(oas_with_counts[columns_to_normalize])
  oas_with_counts[columns_to_normalize] = oas_with_counts[columns_to_normalize].fillna(0)
  oas_with_counts = oas_with_counts[["oa21cd"] + columns_to_normalize]
  return oas_with_counts

# %%
oas_with_counts = pois_by_oa(oas, pois_df)
oas_with_counts
# Out:
# <ipython-input-239-d110157db008>:22: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   oas_with_counts[columns_to_normalize] = oas_with_counts[columns_to_normalize].applymap(lambda x: np.log1p(x))
#         oa21cd   amenity      shop   leisure     total
# 0    E00092201  0.126092  0.000000  0.000000  0.118384
# 1    E00092212  0.466595  0.285714  0.000000  0.473536
# 2    E00092273  0.378275  0.000000  0.537244  0.424402
# 3    E00092013  0.199851  0.000000  0.000000  0.187634
# 4    E00092214  0.126092  0.000000  0.000000  0.118384
# ..         ...       ...       ...       ...       ...
# 535  E00092000  0.436206  0.000000  0.000000  0.409542
# 536  E00092220  0.000000  0.000000  0.000000  0.000000
# 537  E00092223  0.399701  0.000000  0.000000  0.375269
# 538  E00092221  0.000000  0.000000  0.000000  0.000000
# 539  E00092222  0.000000  0.000000  0.000000  0.000000
#
# [540 rows x 5 columns]

# %%
def get_postcodes_from_oas(oas):
  oas_set = set(oas['oa21cd'])
  # %sql USE `ads_2024`;
  postcodes = %sql SELECT oa21cd, pcd7 FROM postcode_oa_lookup WHERE oa21cd in :oas_set;
  postcodes_df = postcodes.DataFrame()
  postcodes_df.columns = ["oa21cd", "postcode"]
  return postcodes_df

# %%
def get_house_transactions_from_oas(oas):
  postcodes = get_postcodes_from_oas(oas)
  postcodes_set = set(postcodes["postcode"])
  # %sql USE `ads_2024`;
  houses = %sql SELECT price, postcode, property_type FROM prices_coordinates_data WHERE postcode in :postcodes_set;
  houses_df = houses.DataFrame()
  houses_df = houses_df.merge(postcodes, on="postcode")

  houses_price = houses_df.groupby("oa21cd")["price"].mean().reset_index()
  houses_price["avg_price"] = houses_price["price"].apply(lambda x: (int(x)//100)*1000)
  houses_price["log_avg_price"] = houses_price["price"].apply(lambda x: np.log1p(x))
  houses_price = houses_price.drop(columns=["price"])

  houses_price["norm_price"] = scaler.fit_transform(houses_price[["avg_price"]])
  houses_price["log_norm_price"] = scaler.fit_transform(houses_price[["log_avg_price"]])
  oas_with_prices = oas.merge(houses_price, on="oa21cd", how="left")

  columns_to_fill = ["avg_price", "log_avg_price", "norm_price", "log_norm_price"]
  oas_with_prices[columns_to_fill] = oas_with_prices[columns_to_fill].fillna(0)
  oas_with_prices = oas_with_prices.drop(columns=["lat", "lon", "urban"])
  return oas_with_prices

# %%
houses = get_house_transactions_from_oas(oas)
houses
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 8426 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 10147 rows affected.
#         oa21cd  avg_price  log_avg_price  norm_price  log_norm_price
# 0    E00092201  4213000.0      12.951132    0.027785        0.249250
# 1    E00092212  3087000.0      12.640128    0.016375        0.175562
# 2    E00092273  7615000.0      13.543150    0.062257        0.389521
# 3    E00092013  8934000.0      13.702791    0.075622        0.427346
# 4    E00092214  2741000.0      12.521495    0.012869        0.147453
# ...

# %%
def election_from_oas(oas):
  oas_set = set(oas["oa21cd"])
  # %sql USE `ads_2024`;
  election_oa = %sql SELECT OA21CD, Partyname, Share FROM election_data WHERE OA21CD in :oas_set;
  election_oa_df = election_oa.DataFrame()
  election_oa_df.columns = ["oa21cd", "party", "share"]
  return election_oa_df

# %%
election_oa_df = election_from_oas(oas)
election_oa_df
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 537 rows affected.
#         oa21cd   party     share
# 0    E00090512  Labour  0.465891
# 1    E00090514  Labour  0.465891
# 2    E00090515  Labour  0.465891
# 3    E00090516  Labour  0.465891
# 4    E00090518  Labour  0.465891
# ..         ...     ...       ...
# 532  E00187816  Labour  0.465891
# 533  E00187825  Labour  0.465891
# 534  E00187841  Labour  0.465891
# 535  E00187842  Labour  0.465891
# 536  E00187849  Labour  0.465891
#
# [537 rows x 3 columns]

# %%
def census_from_oas(oas):
  oas_set = set(oas["oa21cd"])
  # %sql USE `ads_2024`;
  l4 = %sql SELECT OA21CD, L4, total FROM qualification_data WHERE OA21CD IN :oas_set;
  l4_df = l4.DataFrame()
  l4_df.columns = ["oa21cd", "L4", "population"]
  l4_df["L4_percent"] = l4_df["L4"]/l4_df["population"]
  l4_df["L4_norm_percent"] = scaler.fit_transform(l4_df[["L4_percent"]])

  return l4_df

# %%
l4_df = census_from_oas(oas)
l4_df
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 537 rows affected.
#         oa21cd   L4  population  L4_percent  L4_norm_percent
# 0    E00090512  106         251    0.422311         0.338754
# 1    E00090514  192         279    0.688172         0.718299
# 2    E00090515   88         248    0.354839         0.242431
# 3    E00090516  112         263    0.425856         0.343815
# 4    E00090518  185         366    0.505464         0.457465
# ..         ...  ...         ...         ...              ...
# 532  E00187816  239         299    0.799331         0.876990
# 533  E00187825   91         122    0.745902         0.800714
# 534  E00187841  250         331    0.755287         0.814113
# 535  E00187842  439         547    0.802559         0.881599
# ...

# %%
def combined_dfs_on_oa(oas, dfs):
  final_df = oas.copy()
  for df in dfs:
    final_df = final_df.merge(df, on="oa21cd")
  return final_df

# %%
combined_df = combined_dfs_on_oa(oas, [oas_with_counts, houses, election_oa_df, l4_df])
combined_df
# Out:
#         oa21cd       lat       lon  urban   amenity      shop   leisure  \
# 0    E00092201  52.12267  0.162217      0  0.126092  0.000000  0.000000
# 1    E00092212  52.12305  0.169803      0  0.466595  0.285714  0.000000
# 2    E00092273  52.12344  0.096135      0  0.378275  0.000000  0.537244
# 3    E00092013  52.12364  0.053808      0  0.199851  0.000000  0.000000
# 4    E00092214  52.12434  0.162210      0  0.126092  0.000000  0.000000
# ..         ...       ...       ...    ...       ...       ...       ...
# 553  E00092000  52.29704  0.087310      0  0.436206  0.000000  0.000000
# 554  E00092220  52.29723 -0.008590      0  0.000000  0.000000  0.000000
# 555  E00092223  52.29732 -0.005100      0  0.399701  0.000000  0.000000
# 556  E00092221  52.29882  0.000304      0  0.000000  0.000000  0.000000
# 557  E00092222  52.29912 -0.005840      0  0.000000  0.000000  0.000000
#
#         total  avg_price  log_avg_price  norm_price  log_norm_price  \
# ...

# %%
def alpha(val):
  if val == 0:
    return 0.1
  else:
    return val

# %%
def plot_oas_election(df, oa_gdf, fig_ax=None, pos=None):
  share_col = df["share"]
  df["norm_share"] = (share_col - share_col.min()) / (share_col.max() - share_col.min())
  oa_gdf = oa_gdf.merge(df, on="oa21cd")

  oa_gdf["color"] = oa_gdf["party"].map(party_colors)
  oa_gdf["color"] = oa_gdf["color"].fillna("gray")
  alphas = oa_gdf["share"].apply(alpha)

  if not fig_ax:
    fig, ax = plt.subplots(1, 1)
  else:
    fig, ax = fig_ax

  if pos:
    ax = ax[pos[0], pos[1]]
  oa_gdf.plot(ax=ax, color=oa_gdf["color"], linewidth=0.5, edgecolor="black", alpha=alphas)

  ax.set_title("Election Results by Select Output Area", fontsize=8)
  ax.set_xticks([])
  ax.set_yticks([])

# %%
def plot_oas_osm(df, oa_gdf, fig_ax=None, pos=None):
  oa_gdf = oa_gdf.merge(df, on="oa21cd")
  alphas = oa_gdf["total"].apply(alpha)

  if not fig_ax:
    fig, ax = plt.subplots(1, 1, figsize=(8, 8))
  else:
    fig, ax = fig_ax

  if pos:
    ax = ax[pos[0], pos[1]]
  oa_gdf.plot(ax=ax, color="gray", linewidth=0.5, edgecolor="black", alpha=alphas)

  ax.set_title("Amount of OSM nodes by Select Output Area", fontsize=8)
  ax.set_xticks([])
  ax.set_yticks([])

# %%
def plot_oas_houses_price(df, oa_gdf, fig_ax=None, pos=None):
  oa_gdf = oa_gdf.merge(df, on="oa21cd")
  alphas = oa_gdf["log_norm_price"].apply(alpha)

  if not fig_ax:
    fig, ax = plt.subplots(1, 1, figsize=(8, 8))
  else:
    fig, ax = fig_ax

  if pos:
    ax = ax[pos[0], pos[1]]
  oa_gdf.plot(ax=ax, color="gray", linewidth=0.5, edgecolor="black", alpha=alphas)

  ax.set_title("Average log house price by Select Output Area", fontsize=8)
  ax.set_xticks([])
  ax.set_yticks([])

# %%
def plot_oas_degree_qualified(df, oa_gdf, fig_ax=None, pos=None):
  oa_gdf = oa_gdf.merge(df, on="oa21cd")
  alphas = oa_gdf["L4_norm_percent"].apply(alpha)

  if not fig_ax:
    fig, ax = plt.subplots(1, 1, figsize=(8, 8))
  else:
    fig, ax = fig_ax

  if pos:
    ax = ax[pos[0], pos[1]]
  oa_gdf.plot(ax=ax, color="gray", linewidth=0.5, edgecolor="black", alpha=alphas)

  ax.set_title("Percent with degree level qualification Select Output Area", fontsize=8)
  ax.set_xticks([])
  ax.set_yticks([])

# %%
def plot_oas_rural_urban(df, oa_gdf, fig_ax=None, pos=None):
  oa_gdf = oa_gdf.merge(df, on="oa21cd")
  alphas = oa_gdf["urban"].apply(alpha)

  if not fig_ax:
    fig, ax = plt.subplots(1, 1, figsize=(8, 8))
  else:
    fig, ax = fig_ax

  if pos:
    ax = ax[pos[0], pos[1]]
  oa_gdf.plot(ax=ax, color="gray", linewidth=0.5, edgecolor="black", alpha=alphas)

  ax.set_title("Rural or Urban by Select Output Area", fontsize=8)
  ax.set_xticks([])
  ax.set_yticks([])

# %%
# Cambridge and Leeds
latitudes = [52.21, 53.80]
longitudes = [0.08, -1.45]
radius = 10.0
combined_dfs = []

for lat, lon in zip(latitudes, longitudes):
  oas = get_nearby_oas(lat, lon, radius)
  pois = get_pois_radius(lat, lon, radius)
  pois = nearest_oa(pois, oas)
  tags_data = pois_by_oa(oas, pois)
  houses_data = get_house_transactions_from_oas(oas)
  elections_data = election_from_oas(oas)
  census_data = census_from_oas(oas)
  combined_data = combined_dfs_on_oa(oas, [tags_data, houses_data, elections_data, census_data])
  combined_dfs.append(combined_data)
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 609 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 540 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 41737 rows affected.
# <ipython-input-239-d110157db008>:22: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   oas_with_counts[columns_to_normalize] = oas_with_counts[columns_to_normalize].applymap(lambda x: np.log1p(x))
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# ...

# %%
cambridge_df = combined_dfs[0]
leeds_df = combined_dfs[1]
plots = [plot_oas_election, plot_oas_osm, plot_oas_houses_price, plot_oas_degree_qualified, plot_oas_rural_urban]

fig, axes = plt.subplots(5, 2, figsize=(12, 12))

for i in range(5):
  plt.sca(axes[i, 0])
  plots[i](cambridge_df, oa_gdf, (fig, axes), [i, 0])
  plt.sca(axes[i, 1])
  plots[i](leeds_df, oa_gdf, (fig, axes), [i, 1])

plt.tight_layout()
plt.show()

# %% [markdown]
# The above cell compares Cambridge and Leeds and their respective rural areas. I wanted to make a side by side comparison as I was measuring the **amount** of political polarisation (not just that it existed). You can somewhat see that the urban/rural divide of Leeds is greater (easiest to see in OSM nodes graph), and also that Leeds is more polarised, Labour/LibDem vs Labour/Conservative and also in the share values of output areas.
#
# Ultimately this is my overall hypothesis, although the hypothesis is not perfect.

# %% [markdown]
# ## Address

# %% [markdown]
# ## Conclusions
#
# The below code is for marking purpuses only, and not part of your project. It helps us gather the data we need without asking you for database credentials, and scouring github pages. This is mandatory. If the code does not work for you, let us know immediately.

# %% [markdown]
# 1) Please re-run the code from Practical 1 to help us see the contents of your database. We recommend you include all data sources there, but some smaller inputs are fine to use as files.

# %%
# %sql USE `ads_2024`;
tables = %sql SHOW TABLES;

for row in tables:
    table_name = row[0]
    print(f"\nTable: {table_name}")

    table_status = %sql SHOW TABLE STATUS LIKE '{table_name}';
    approx_row_count = table_status[0][4] if table_status else 'Unable to fetch row count'
    print("\nApprox Row Count:", approx_row_count//100000/10, "M")

    first_5_rows = %sql SELECT * FROM `{table_name}` LIMIT 5;
    print(first_5_rows)

    indices = %sql SHOW INDEX FROM `{table_name}`;
    if indices:
        print("\nIndices:")
        for index in indices:
            print(f" - {index[2]} ({index[10]}): Column {index[4]}")
    else:
        print("\nNo indices set on this table.")
# Out:
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 0 rows affected.
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 10 rows affected.
#
# Table: election_data
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 1 rows affected.
#
# Approx Row Count: 0.1 M
#  * mariadb+pymysql://admin:***@database-ads-gd496.cgrre17yxw11.eu-west-2.rds.amazonaws.com?local_infile=1
# 5 rows affected.
# +-----------+-------------+------------------+------------+-------------+------------------+-----------+-------------------+----------+-----------+-----------+
# |   ONSID   | ONSregionID | Constituencyname | Regionname | Countryname | Constituencytype | Partyname | Partyabbreviation |  Share   |   OA21CD  |    Name   |
# ...

# %% [markdown]
# 2) Please paste a link to your fynesse library below, and make sure it's publically accessible. Also run the code below, and make sure it worked, printing out the contents of your library.

# %%
fynesse_url = '<your-url-library-here>'

# %%
import fynesse
import os

print('FYNESSE STRUCTURE:')
package_path = os.path.dirname(fynesse.__file__)
for root, dirs, files in os.walk(package_path):
    level = root.replace(package_path, '').count(os.sep)
    indent = ' ' * 4 * level
    print(f"{indent}{os.path.basename(root)}/")
    sub_indent = ' ' * 4 * (level + 1)
    for f in files:
        print(f"{sub_indent}{f}")

print('FILE CONTENTS')
for root, dirs, files in os.walk(package_path):
    for file in files:
        file_path = os.path.join(root, file)
        print(f"--- Contents of {file_path} ---\n")
        try:
            with open(file_path, "r", encoding="utf-8") as f:
                print(f.read())
        except Exception as e:
            print(f"Could not read {file_path}: {e}")
        print("\n" + "-" * 50 + "\n")
